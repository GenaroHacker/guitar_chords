# %% [markdown]
# <a href="https://colab.research.google.com/github/GenaroHacker/guitar_chords/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Import
# %%capture
# !git clone https://github.com/GenaroHacker/guitar_chords.git
# !pip install pillow
from guitar_chords.chord_library import roots, chords
from guitar_chords.note import Note
from guitar_chords.build_progression import build_progression
from guitar_chords.display_progression import display_progression

# %%
print(roots)
print(chords)
note1 = Note("C")
print(note1.transpose(1))
blues = build_progression("A", [["I", "7"],["I", "7"],["I", "7"],["I", "7"],
                                  ["IV", "7"],["IV", "7"],["I", "7"],["I", "7"],
                                  ["V", "7"],["IV", "7"],["I", "7"],["V", "7"],])
print(blues)
display_progression(blues,4)
# Out:
# ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
# ['11', '13', '13sus4', '5', '6', '7#5', '7#9', '7add4', '7b5', '7b9', '7', '7sus2', '7sus4', '9#5', '9b5', '9', '9sus4', 'add2add4', 'add2', 'add4', 'add9', 'aug', '', 'm11', 'm13', 'm6', 'm7#5', 'm7add4', 'm7b5', 'm7', 'm9', 'madd2add4', 'madd2', 'madd4', 'madd9', 'maj11', 'maj13', 'maj7#5', 'maj7b5', 'maj7', 'maj9', 'mmaj7', 'mmaj9', 'sus2', 'sus4']
# C#
# ['A7', 'A7', 'A7', 'A7', 'D7', 'D7', 'A7', 'A7', 'E7', 'D7', 'A7', 'E7']
# <PIL.Image.Image image mode=RGBA size=480x384 at 0x7F3E11D88280>
